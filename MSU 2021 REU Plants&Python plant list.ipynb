# %% [markdown]
# As an exercise in Plants&Python, students select plants from major angiosperm clades and create a "list of lists" to learn about indexing.
#
# Below is a sampling of plants students chose in one, overall list.

# %%
# MONOCOTS

poaceae = ["sugarcane", "maize", "wheat","oryza_sativa","zea_mays","hordeum_vulgare",
           "rice","millet","barley","Actinocladum verticillatum", "Aristida adscensionis",
          'Triticum_aestivum','Phyllostachis_edulis',"triticum spelta","Avena sativa",
           "Secale cereale","bamboo"]
arecaceae = ["dates", "coconuts", "palm kernels","Cocos_nucifera","Elaeis_guineensis",
             "Copernicia_prunifera","Borassus_flabellifer","coir"]
araceae = [ "Lysichiton camtschatcensis","Orontium aquaticum", "Spirodela polyrrhiza"]
orchidaceae = ["grammatophyllum_speciosum", "prosthechea_cochleata", "vanda_sanderiana",
               'Paphiopedilum concolor ', 'Dendrobium catenatum', 'Phalaenopsis equestris']
amaryllidaceae = ["garlic", "onion","chives", "shallot"]
musaceae = ["bananas", "plantains", "manila fibre",'Musa acuminata', 'Musa balbisiana',
            'Musa paradisiaca']
lilaceae = ["Lilium_longiflorum"]

# ROSIDS

fabaceae = ["string beans", "chick peas", "soybeans", "pea","Lens_culinaris",
            "cajanus_cajan","Phaseolus vulgaris", "Phaseolus coccineus",
            "Phaseolus dumosus",'Glycine_max','Medicago_sativa','Arachis_hypogaea',
           "almendro tree","acacia"]
rosaceae = ["pears", "apples", "strawberries","peach","plum","almonds",
            "Fragaria x ananassa",'Malus domestica','Rubus ulmifolius', 'Prunus dulcis',
           'Prunus_persica','Pyrus_pyrifolia',"nectarines", "apricots","cherries","raspberries"]
cucurbitaceae = ["cucumis_sativus", "lagenaria_siceraria", "citrullus_lanatus","squash",
                 "pumpkin", "zucchini", "gourds", "calabash", "watermelon", "cucumber",
                 "melon"]
picramniaceae = ["alvaradoa_amorphoides", "nothotalisia_cancellata", "picramnia_acreana"]
brassicaceae = ["Brassica_oleracea", "Raphanus_raphanistrum",'Brassica rapa',
                'Arabidopsis thaliana']
malvaceae = ["okra", "cottonseed", "kola nuts","cocoa beans"]
violaceae = [ 'Viola adunca', 'Viola aethnensis', 'Viola biflora']
geraniaceae = ["Geranium_maculatum"]
rutaceae=["oranges","Grapefruit","Lemons"]
passifloraceae=["passion vine"]

# ASTERIDS

solanaceae = ["green chilies", "eggplant", "tomatoes","potatoes","chiles","green chilies",
              'Capsicum_annuum','Solanum_tuberosum','Solanum_lycopersicum',
              'Nicotiana_tabacum']
apiaceae = ["celery", "dill","carrots","fennel","coriander","cilantro","Ferula tingitana",
           "Daucus carota","Pimpinella anisum", "Heracleum mantegazzianum","Conium maculatum"]
ericaceae = ["cranberries", "blueberries",'Vaccinium_corymbosum','Vaccinium_macrocarpon',
             'Vaccinium_membranaceum','Vaccinium boreale', 'Vaccinium oxycoccos']
griseliniaceae = ["griselinia_lucida", "griselinia_littoralis", "griselinia_jodinifolia"]
goodeniaceae = ["brunonia_australis", "scaevola_taccada", "selliera_radicans"]
convolvulaceae = ["sweet potato", "morning glory","Ipomoea_batatas","ipomoea purpurea",
                  "Cuscuta reflexa","Evolvulus alsinoides"]
gesneriaceae = ["saintpaulia_ionantha",'Saintpaulia inconspicua']
asteraceae = ["Sunflower_Seeds","Artichokes","Chicory_roots",'Helianthus annuus',
              'Lactuca sativa',"safflower seed"]
rubiaceae = ['Coffea arabiga', 'Rubia agostinhoi', 'Galium album' ]
oleaceae = ["olives", "jasmine"]
cornaceae = ["cornus", "alangium"]
apocynaceae = ["Asclepias syriaca"]

# AUSTROBAILEYALES

schisandraceae = ["badian"]

# MAGNOLIIDS

magnoliaceae = ['Magnolia vrieseana', 'Magnolia virginiana', 'Magnolia grandiflora']
lauraceae = ['Persea americana', 'Laurus nobilis']

# create angiosperm clade lists

monocots = [poaceae, arecaceae, orchidaceae, amaryllidaceae,musaceae, araceae, lilaceae]
rosids = [fabaceae, rosaceae, cucurbitaceae, picramniaceae, brassicaceae, malvaceae, violaceae,
         geraniaceae, rutaceae, passifloraceae]
asterids = [solanaceae, ericaceae, griseliniaceae, goodeniaceae, apiaceae,
            convolvulaceae, gesneriaceae, asteraceae, rubiaceae, oleaceae, cornaceae, apocynaceae]
austrobaileyales=[schisandraceae]
magnoliids=[magnoliaceae, lauraceae]

# create overall list

my_plants = [austrobaileyales, magnoliids, monocots, rosids, asterids]

print(my_plants)
